# %%
import numpy as np
import pandas as pd
import random
import string
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from keras.callbacks import ReduceLROnPlateau
import keras
from scipy.optimize import curve_fit
import time
import kaggle as kg
import os
import transformers as tr

CTX_LENGTH = 30
TEXT_LENGTH = 30

# Descărcăm CSV-ul de pe Kaggle
competition_name = 'nlp-getting-started'
file_name = 'train.csv'

kg.api.competition_download_file(competition_name, file_name, path='.')

# Încărcăm într-un DataFrame Pandas
df = pd.read_csv(file_name)

# Tokenizer pe litere
# Hot-swappable cu tokenizerele HuggingFace
class LetterTokenizer:
    def __init__(self, txt):
        self.letters = list(set(''.join(txt)))
        self.vocab_size = len(self.letters)
        self.token_to_id = {char: idx for idx, char in enumerate(self.letters)}
        self.id_to_token = {idx: char for idx, char in enumerate(self.letters)}
        self.pad_token_id = self.token_to_id[" "]  # Folosim space pt padding

    def encode(self, text):
        text = text.lower()  # Ignorăm case-ul textului
        return [self.token_to_id[char] for char in text if char in self.token_to_id]

    def decode(self, token_ids):
        return "".join([self.id_to_token[token_id] for token_id in token_ids])

class WordTokenizer:
    def __init__(self, txt):
        # Create a set of unique words from the text
        words = set(''.join(txt).split())
        self.words = list(words)
        self.vocab_size = len(self.words)
        
        # Create mappings from words to IDs and vice versa
        self.token_to_id = {word: idx for idx, word in enumerate(self.words)}
        self.id_to_token = {idx: word for idx, word in enumerate(self.words)}
        
        # Use a special token for padding (optional)
        self.pad_token = "<PAD>"
        self.pad_token_id = self.vocab_size
        self.token_to_id[self.pad_token] = self.pad_token_id
        self.id_to_token[self.pad_token_id] = self.pad_token
        
        # Update vocabulary size to include pad token
        self.vocab_size += 1

    def encode(self, text):
        text = text.lower()  # Ignore case of the text
        return [self.token_to_id[word] for word in text.split() if word in self.token_to_id]

    def decode(self, token_ids):
        return " ".join([self.id_to_token[token_id] for token_id in token_ids])

from sacremoses import MosesTokenizer, MosesDetokenizer
class WordMosesTokenizer:
    def __init__(self, txt):
        # Initialize Moses tokenizer and detokenizer
        self.moses_tokenizer = MosesTokenizer()
        self.moses_detokenizer = MosesDetokenizer()
        
        # Tokenize the text and create a set of unique words
        words = set(self.moses_tokenizer.tokenize(''.join(txt)))
        self.words = list(words)
        self.vocab_size = len(self.words)
        
        # Create mappings from words to IDs and vice versa
        self.token_to_id = {word: idx for idx, word in enumerate(self.words)}
        self.id_to_token = {idx: word for idx, word in enumerate(self.words)}
        
        # Use a special token for padding (optional)
        self.pad_token = "<PAD>"
        self.pad_token_id = self.vocab_size
        self.token_to_id[self.pad_token] = self.pad_token_id
        self.id_to_token[self.pad_token_id] = self.pad_token
        
        # Update vocabulary size to include pad token
        self.vocab_size += 1

    def encode(self, text):
        # Tokenize the text using Moses tokenizer
        tokens = self.moses_tokenizer.tokenize(text.lower())
        return [self.token_to_id[token] for token in tokens if token in self.token_to_id]

    def decode(self, token_ids):
        # Convert token IDs back to words
        tokens = [self.id_to_token[token_id] for token_id in token_ids]
        # Detokenize the words using Moses detokenizer
        return self.moses_detokenizer.detokenize(tokens)

#tokenizer = tr.BertTokenizer.from_pretrained('bert-base-uncased')
tokenizer = WordTokenizer(df.text.to_list())
print("Vocabulary size " + str(tokenizer.vocab_size))

# Encodăm toate paragrafurile alese
paragraphs = df.text.apply(lambda x: tokenizer.encode(x)).to_list()

# Afișăm o histogramă cu lungimile să
# știm ~ la ce lungime să uniformizăm
lens = [len(x) for x in paragraphs]
plt.hist(lens, bins=20)
# Out:
# train.csv: Skipping, found more recently modified local copy (use --force to force download)
# Vocabulary size 31560
# (array([ 95., 105., 473., 305., 929., 505., 990., 446., 927., 408., 715.,
#         308., 496., 208., 314., 137., 157.,  46.,  39.,  10.]),
#  array([ 0. ,  1.5,  3. ,  4.5,  6. ,  7.5,  9. , 10.5, 12. , 13.5, 15. ,
#         16.5, 18. , 19.5, 21. , 22.5, 24. , 25.5, 27. , 28.5, 30. ]),
#  <BarContainer object of 20 artists>)

# %%
import random


def reset_numpy_seed(seed_value=42):
  try:
    # Set NumPy random seed
    import numpy as np
    np.random.seed(seed_value)
    print(f'NumPy random seed set with value: {seed_value}')
  except Exception as e:
    print(f'NumPy random seed was not set: {e}')
  return


def reset_tensorflow_seed(seed_value=42):
  try:
    # Set TensorFlow random seed
    import tensorflow as tf
    success = False
    # Here we have 2 different ways to set the seed
    # depending on the version of TensorFlow
    try:
      tf.random.set_seed(seed_value)
      success = True
    except Exception as e:
      pass
    try:
      tf.set_random_seed(seed_value)
      success = True
    except Exception as e:
      pass
    if success:
      print(f'TensorFlow random seed set with value: {seed_value}')
    else:
      print(f'TensorFlow random seed was not set')
  except Exception as e:
    print(f'TensorFlow random seed was not set: {e}')
  return


def reset_torch_seed(seed_value=42):
  try:
    # Set PyTorch random seed
    import torch
    torch.manual_seed(seed_value)
    if torch.cuda.is_available():
      torch.cuda.manual_seed(seed_value)
      torch.cuda.manual_seed_all(seed_value)  # if you are using multiple GPUs
    print(f'PyTorch random seed set with value: {seed_value}')
  except Exception as e:
    print(f'PyTorch random seed was not set: {e}')
  return


def set_random_seeds(seed_value=42):
  # Set Python random seed
  random.seed(seed_value)
  reset_numpy_seed(seed_value)
  reset_tensorflow_seed(seed_value)
  reset_torch_seed(seed_value)
  return


if __name__ == '__main__':
  # Set the desired seed value
  seed = 42

  # Set random seeds
  set_random_seeds(seed)
# Out:
# NumPy random seed set with value: 42
# TensorFlow random seed set with value: 42
# PyTorch random seed set with value: 42

# %%
def uniformize_length(paragraph, length, rev=False):
    if len(paragraph) > length:
        return paragraph[:length] if not rev else paragraph[-length:]
    else:
        return (paragraph + [tokenizer.pad_token_id] * (length - len(paragraph))) if not rev else ([tokenizer.pad_token_id] * (length - len(paragraph)) + paragraph)

# Uniformizăm lungimile paragrafurilor
dataset = [uniformize_length(x, TEXT_LENGTH) for x in paragraphs]
inputs = np.array(dataset)

# Formăm np-array-urile de X,y cu input/output
def prepare_input_output(inputs, targets, ctx_length, vocab_size):
    X = []
    y = []
    for idx in range(len(inputs)):
        for i in range(0, inputs[idx].shape[0] - ctx_length + 1):
            input_block = inputs[idx][i:i + ctx_length]
            #input_block = tf.one_hot(input_block, depth=vocab_size).numpy().flatten()
            target_block = tf.one_hot(targets[idx], depth=2).numpy()

            X.append(input_block)
            y.append(target_block)

    return np.array(X), np.array(y)

X, y = prepare_input_output(inputs, df.target, CTX_LENGTH, tokenizer.vocab_size)

# %%
# Verificare hardware CPU/GPU
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
if len(tf.config.list_physical_devices('GPU')) > 0:
    print("Using GPU")
else:
    print("Using CPU")

# Definim arhitectura modelului

# RNN
model = Sequential(
    [
        keras.layers.Embedding(tokenizer.vocab_size, 512, input_length=X.shape[1]),
        keras.layers.SpatialDropout1D(0.4),
        keras.layers.LSTM(512, dropout=0.2, recurrent_dropout=0.2),
        keras.layers.Dense(2, activation="softmax"),
    ]
)
# Out:
# Num GPUs Available:  0
# Using CPU
# c:\Python310\lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# Funcție care să se plieze pe loss (+/- logaritmic)
def logarithmic_decay(x, a, b, c, d):
    return -(a * np.log(x * b + c) + d)         # Adaptat din formula pt cross-entropy loss

# Average-uim valorile pt un curve mai smooth
def average_every_n_values(arr, n):
    return np.mean(np.pad(arr, (0, n - len(arr) % n), mode='edge').reshape(-1, n), axis=1)

# O clasă custom cu un simplu curve fitter ca să putem
# prezice loss-ul în timp real pentru a avea un 
# feedback mai bun asupra performanței modelului
# fără să antrenăm o epocă întreagă
class LossHistory(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs):
        self.losses = []
        self.history_losses = []
        self.offset = 30                # Ignorăm anomalii de la început
        self.average_values = 5         # Smoothing
    
    def on_epoch_begin(self, epoch, logs=None):
        # Luăm nr de batch-uri pt epoca curentă
        self.total_batches = self.params['steps']
        self.epoch_time = time.time()
        self.offset = int(self.total_batches * 0.015)

    def on_batch_end(self, batch, logs):
        logs = logs or {}
        self.history_losses.append(logs.get('loss'))
        self.losses.append(logs.get('loss'))

        # Updatăm loss-ul prezis dacă avem destule date
        if len(self.losses) > self.offset + self.average_values * 3 + 1:  # Sigur avem destule puncte
            mean_losses = np.array(self.losses[self.offset:])
            mean_losses = average_every_n_values(mean_losses, self.average_values)
            x_data = np.arange(1, len(mean_losses) + 1)
            y_data = np.array(mean_losses)

            try:
                popt, _ = curve_fit(logarithmic_decay, x_data, y_data, maxfev=10000)    # Facem un curve fitting cu funcția noastră
                self.popt = popt
                x_final = (self.total_batches - self.offset - self.average_values * 3 + 1) / self.average_values
                final_loss = logarithmic_decay(x_final, *popt)     # Prezicem valoare de la ultimul batch

                current_loss = logarithmic_decay(len(mean_losses), *popt)
                final_loss = max(min(final_loss + current_loss - logs.get('loss'), 99), 0)
                logs['predicted_final_loss'] = final_loss
            except: pass
            
            # Accelerația loss-ului în timp
            logs['loss_delta_time'] = (mean_losses[0] - mean_losses[-1]) / (time.time() - self.epoch_time) * 1000
        else:
            logs['loss_delta_time'] = (self.losses[0] - self.losses[-1]) / (time.time() - self.epoch_time) * 1000

    def on_epoch_end(self, epoch, logs):
        logs = logs or {}
        self.losses = []

loss_history = LossHistory()

# %%
# Compilăm modelul + optimizer-ul
optimizer = Adam(learning_rate=1e-3)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Antrenăm modelul cu validation split
print('Starting training...')
history = model.fit(X, y, epochs=20, batch_size=128, callbacks=[learning_rate_reduction, loss_history], shuffle=True, validation_split=0.1)

# Afișăm loss-ul per epoci
plt.plot(history.history['loss'])
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
# Starting training...
# Epoch 1/20
# 17/54 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - accuracy: 0.5393 - loss: 0.6918 - loss_delta_time: 1.2888 - predicted_final_loss: 0.6829
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_23264\2331375621.py:3: RuntimeWarning: invalid value encountered in log
#   return -(a * np.log(x * b + c) + d)         # Adaptat din formula pt cross-entropy loss
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_23264\2331375621.py:39: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, _ = curve_fit(logarithmic_decay, x_data, y_data, maxfev=10000)    # Facem un curve fitting cu funcția noastră
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 19s 316ms/step - accuracy: 0.5618 - loss: 0.6861 - loss_delta_time: 1.1945 - predicted_final_loss: 0.6868 - val_accuracy: 0.7218 - val_loss: 0.5608 - learning_rate: 0.0010
# Epoch 2/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 288ms/step - accuracy: 0.7664 - loss: 0.5219 - loss_delta_time: 6.4081 - predicted_final_loss: 0.5141 - val_accuracy: 0.7441 - val_loss: 0.5402 - learning_rate: 0.0010
# Epoch 3/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 288ms/step - accuracy: 0.8443 - loss: 0.4063 - loss_delta_time: -1.6008 - predicted_final_loss: 0.3920 - val_accuracy: 0.7572 - val_loss: 0.5919 - learning_rate: 0.0010
# Epoch 4/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 289ms/step - accuracy: 0.8854 - loss: 0.3264 - loss_delta_time: 5.5508 - predicted_final_loss: 0.3061 - val_accuracy: 0.7415 - val_loss: 0.6084 - learning_rate: 0.0010
# Epoch 5/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9173 - loss: 0.2558 - loss_delta_time: 5.8531 - predicted_final_loss: 0.2479
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 17s 309ms/step - accuracy: 0.9172 - loss: 0.2559 - loss_delta_time: 5.7583 - predicted_final_loss: 0.2479 - val_accuracy: 0.7533 - val_loss: 0.6746 - learning_rate: 0.0010
# Epoch 6/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 17s 310ms/step - accuracy: 0.9375 - loss: 0.2049 - loss_delta_time: 2.5479 - predicted_final_loss: 0.1941 - val_accuracy: 0.7375 - val_loss: 0.7251 - learning_rate: 5.0000e-04
# Epoch 7/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9482 - loss: 0.1752 - loss_delta_time: 1.2550 - predicted_final_loss: nan
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 17s 316ms/step - accuracy: 0.9482 - loss: 0.1750 - loss_delta_time: 1.2420 - predicted_final_loss: nan - val_accuracy: 0.7415 - val_loss: 0.8170 - learning_rate: 5.0000e-04
# Epoch 8/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 18s 329ms/step - accuracy: 0.9505 - loss: 0.1531 - loss_delta_time: 2.5562 - predicted_final_loss: 0.1570 - val_accuracy: 0.7297 - val_loss: 0.8564 - learning_rate: 2.5000e-04
# Epoch 9/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9584 - loss: 0.1410 - loss_delta_time: 6.1042 - predicted_final_loss: 0.1337
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 288ms/step - accuracy: 0.9584 - loss: 0.1408 - loss_delta_time: 6.0310 - predicted_final_loss: 0.1336 - val_accuracy: 0.7349 - val_loss: 0.8887 - learning_rate: 2.5000e-04
# Epoch 10/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 290ms/step - accuracy: 0.9595 - loss: 0.1325 - loss_delta_time: 5.6047 - predicted_final_loss: 0.1246 - val_accuracy: 0.7349 - val_loss: 0.8818 - learning_rate: 1.2500e-04
# Epoch 11/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9590 - loss: 0.1238 - loss_delta_time: 8.2840 - predicted_final_loss: 0.1192
# Epoch 11: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 291ms/step - accuracy: 0.9591 - loss: 0.1236 - loss_delta_time: 8.1722 - predicted_final_loss: 0.1192 - val_accuracy: 0.7388 - val_loss: 0.9304 - learning_rate: 1.2500e-04
# Epoch 12/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 289ms/step - accuracy: 0.9621 - loss: 0.1161 - loss_delta_time: 6.5567 - predicted_final_loss: 0.1089 - val_accuracy: 0.7402 - val_loss: 0.9054 - learning_rate: 6.2500e-05
# Epoch 13/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9613 - loss: 0.1136 - loss_delta_time: 4.0557 - predicted_final_loss: nan
# Epoch 13: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 18s 327ms/step - accuracy: 0.9614 - loss: 0.1135 - loss_delta_time: 3.9901 - predicted_final_loss: nan - val_accuracy: 0.7388 - val_loss: 0.9241 - learning_rate: 6.2500e-05
# Epoch 14/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 289ms/step - accuracy: 0.9641 - loss: 0.1139 - loss_delta_time: 5.5472 - predicted_final_loss: 0.1070 - val_accuracy: 0.7323 - val_loss: 0.9272 - learning_rate: 3.1250e-05
# Epoch 15/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9613 - loss: 0.1152 - loss_delta_time: 8.2432 - predicted_final_loss: 0.1069
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 295ms/step - accuracy: 0.9614 - loss: 0.1150 - loss_delta_time: 8.1330 - predicted_final_loss: 0.1069 - val_accuracy: 0.7323 - val_loss: 0.9173 - learning_rate: 3.1250e-05
# Epoch 16/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 300ms/step - accuracy: 0.9648 - loss: 0.1070 - loss_delta_time: 7.0923 - predicted_final_loss: 0.1031 - val_accuracy: 0.7349 - val_loss: 0.9312 - learning_rate: 1.5625e-05
# Epoch 17/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9657 - loss: 0.1072 - loss_delta_time: 8.1437 - predicted_final_loss: 0.1025
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1e-05.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 297ms/step - accuracy: 0.9657 - loss: 0.1071 - loss_delta_time: 8.0170 - predicted_final_loss: 0.1025 - val_accuracy: 0.7323 - val_loss: 0.9335 - learning_rate: 1.5625e-05
# Epoch 18/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 297ms/step - accuracy: 0.9618 - loss: 0.1110 - loss_delta_time: 7.9641 - predicted_final_loss: 0.1048 - val_accuracy: 0.7336 - val_loss: 0.9287 - learning_rate: 1.0000e-05
# Epoch 19/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 289ms/step - accuracy: 0.9664 - loss: 0.1043 - loss_delta_time: 7.8943 - predicted_final_loss: 0.1001 - val_accuracy: 0.7323 - val_loss: 0.9373 - learning_rate: 1.0000e-05
# Epoch 20/20
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 16s 290ms/step - accuracy: 0.9627 - loss: 0.1064 - loss_delta_time: 7.6545 - predicted_final_loss: 0.0990 - val_accuracy: 0.7310 - val_loss: 0.9402 - learning_rate: 1.0000e-05

# %%
def logarithmic_decay_test(x, a, b, c, d):
    return -(a * np.log(x * b + c) + d)

def calc_curve(value_count):
    mean_losses = np.array(loss_history.history_losses[loss_history.offset:value_count])
    mean_losses = average_every_n_values(mean_losses, loss_history.average_values)
    x_data = np.arange(1, len(mean_losses) + 1)
    y_data = np.array(mean_losses)

    popt, _ = curve_fit(logarithmic_decay_test, x_data, y_data, maxfev=10000)
    return mean_losses, popt, logarithmic_decay_test(np.arange(0, value_count).astype('float64'), *popt)

# Afișăm loss-ul per batch-uri + loss-ul prezis (pentru prima epocă)
look_back_count = min(2000, len(loss_history.history_losses))
mean_losses, popt, lst = calc_curve(look_back_count)
plt.plot(loss_history.history_losses[loss_history.offset:look_back_count:loss_history.average_values])
plt.plot(mean_losses)
plt.plot(lst)
plt.plot()
plt.title('Training Loss')
plt.xlabel('Averaged Batch')
plt.ylabel('Loss')
plt.show()

print(popt)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_23264\1140400584.py:2: RuntimeWarning: invalid value encountered in log
#   return -(a * np.log(x * b + c) + d)
# [ 0.16603475  1.37223221  1.41688345 -0.99251303]

# %%
# Prezicem clasa următoarei secvențe
def predict_class(prompt):
    prompt_tokens = tokenizer.encode(prompt)
    
    input_tokens = uniformize_length(prompt_tokens, CTX_LENGTH)
    # Trebuie să ne potrivim dimenisunile la [samples, time_steps]
    input_t = np.array(input_tokens)
    input_t = input_t.reshape(1, CTX_LENGTH)

    output = model.predict(input_t, verbose=0)
    output = np.asarray(output).astype('float64')
    
    return output[0, 1] > output[0, 0]

# Prompt de test
prompt = "Great, I'm so happy"
#prompt = "Horrible death and fire burst aflame. Dead people ambulance."
print(predict_class(prompt))
# Out:
# False

# %%
file_name = 'test.csv'
kg.api.competition_download_file(competition_name, file_name, path='.')

df_test = pd.read_csv(file_name)

# Evaluăm datele de test
submission = pd.DataFrame()
for i in range(len(df_test)):
    pred = predict_class(df_test.text[i])

    #print(f"{df_test.text[i]}, {pred=}")
    print(f"{i=}/{len(df_test)}")
    submission = submission._append({'id': df_test.id[i], 'target': pred}, ignore_index=True)

submission.sample()
# Out:
# test.csv: Skipping, found more recently modified local copy (use --force to force download)
# i=0/3263
# i=1/3263
# i=2/3263
# i=3/3263
# i=4/3263
# i=5/3263
# i=6/3263
# i=7/3263
# i=8/3263
# i=9/3263
# i=10/3263
# i=11/3263
# i=12/3263
# i=13/3263
# i=14/3263
# i=15/3263
# i=16/3263
# i=17/3263
# i=18/3263
# i=19/3263
# i=20/3263
# i=21/3263
# i=22/3263
# i=23/3263
# i=24/3263
# i=25/3263
# i=26/3263
# i=27/3263
# i=28/3263
# i=29/3263
# i=30/3263
# i=31/3263
# i=32/3263
# i=33/3263
# i=34/3263
# i=35/3263
# i=36/3263
# i=37/3263
# i=38/3263
# i=39/3263
# i=40/3263
# i=41/3263
# i=42/3263
# i=43/3263
# i=44/3263
# i=45/3263
# i=46/3263
# i=47/3263
# i=48/3263
# i=49/3263
# i=50/3263
# i=51/3263
# i=52/3263
# i=53/3263
# i=54/3263
# i=55/3263
# i=56/3263
# i=57/3263
# i=58/3263
# i=59/3263
# i=60/3263
# i=61/3263
# i=62/3263
# i=63/3263
# i=64/3263
# i=65/3263
# i=66/3263
# i=67/3263
# i=68/3263
# i=69/3263
# i=70/3263
# i=71/3263
# i=72/3263
# i=73/3263
# i=74/3263
# i=75/3263
# i=76/3263
# i=77/3263
# i=78/3263
# i=79/3263
# i=80/3263
# i=81/3263
# i=82/3263
# i=83/3263
# i=84/3263
# i=85/3263
# i=86/3263
# i=87/3263
# i=88/3263
# i=89/3263
# i=90/3263
# i=91/3263
# i=92/3263
# i=93/3263
# i=94/3263
# i=95/3263
# i=96/3263
# i=97/3263
# i=98/3263
# i=99/3263
# i=100/3263
# i=101/3263
# i=102/3263
# i=103/3263
# i=104/3263
# i=105/3263
# i=106/3263
# i=107/3263
# i=108/3263
# i=109/3263
# i=110/3263
# i=111/3263
# i=112/3263
# i=113/3263
# i=114/3263
# i=115/3263
# i=116/3263
# i=117/3263
# i=118/3263
# i=119/3263
# i=120/3263
# i=121/3263
# i=122/3263
# i=123/3263
# i=124/3263
# i=125/3263
# i=126/3263
# i=127/3263
# i=128/3263
# i=129/3263
# i=130/3263
# i=131/3263
# i=132/3263
# i=133/3263
# i=134/3263
# i=135/3263
# i=136/3263
# i=137/3263
# i=138/3263
# i=139/3263
# i=140/3263
# i=141/3263
# i=142/3263
# i=143/3263
# i=144/3263
# i=145/3263
# i=146/3263
# i=147/3263
# i=148/3263
# i=149/3263
# i=150/3263
# i=151/3263
# i=152/3263
# i=153/3263
# i=154/3263
# i=155/3263
# i=156/3263
# i=157/3263
# i=158/3263
# i=159/3263
# i=160/3263
# i=161/3263
# i=162/3263
# i=163/3263
# i=164/3263
# i=165/3263
# i=166/3263
# i=167/3263
# i=168/3263
# i=169/3263
# i=170/3263
# i=171/3263
# i=172/3263
# i=173/3263
# i=174/3263
# i=175/3263
# i=176/3263
# i=177/3263
# i=178/3263
# i=179/3263
# i=180/3263
# i=181/3263
# i=182/3263
# i=183/3263
# i=184/3263
# i=185/3263
# i=186/3263
# i=187/3263
# i=188/3263
# i=189/3263
# i=190/3263
# i=191/3263
# i=192/3263
# i=193/3263
# i=194/3263
# i=195/3263
# i=196/3263
# i=197/3263
# i=198/3263
# i=199/3263
# i=200/3263
# i=201/3263
# i=202/3263
# i=203/3263
# i=204/3263
# i=205/3263
# i=206/3263
# i=207/3263
# i=208/3263
# i=209/3263
# i=210/3263
# i=211/3263
# i=212/3263
# i=213/3263
# i=214/3263
# i=215/3263
# i=216/3263
# i=217/3263
# i=218/3263
# i=219/3263
# i=220/3263
# i=221/3263
# i=222/3263
# i=223/3263
# i=224/3263
# i=225/3263
# i=226/3263
# i=227/3263
# i=228/3263
# i=229/3263
# i=230/3263
# i=231/3263
# i=232/3263
# i=233/3263
# i=234/3263
# i=235/3263
# i=236/3263
# i=237/3263
# i=238/3263
# i=239/3263
# i=240/3263
# i=241/3263
# i=242/3263
# i=243/3263
# i=244/3263
# i=245/3263
# i=246/3263
# i=247/3263
# i=248/3263
# i=249/3263
# i=250/3263
# i=251/3263
# i=252/3263
# i=253/3263
# i=254/3263
# i=255/3263
# i=256/3263
# i=257/3263
# i=258/3263
# i=259/3263
# i=260/3263
# i=261/3263
# i=262/3263
# i=263/3263
# i=264/3263
# i=265/3263
# i=266/3263
# i=267/3263
# i=268/3263
# i=269/3263
# i=270/3263
# i=271/3263
# i=272/3263
# i=273/3263
# i=274/3263
# i=275/3263
# i=276/3263
# i=277/3263
# i=278/3263
# i=279/3263
# i=280/3263
# i=281/3263
# i=282/3263
# i=283/3263
# i=284/3263
# i=285/3263
# i=286/3263
# i=287/3263
# i=288/3263
# i=289/3263
# i=290/3263
# i=291/3263
# i=292/3263
# i=293/3263
# i=294/3263
# i=295/3263
# i=296/3263
# i=297/3263
# i=298/3263
# i=299/3263
# i=300/3263
# i=301/3263
# i=302/3263
# i=303/3263
# i=304/3263
# i=305/3263
# i=306/3263
# i=307/3263
# i=308/3263
# i=309/3263
# i=310/3263
# i=311/3263
# i=312/3263
# i=313/3263
# i=314/3263
# i=315/3263
# i=316/3263
# i=317/3263
# i=318/3263
# i=319/3263
# i=320/3263
# i=321/3263
# i=322/3263
# i=323/3263
# i=324/3263
# i=325/3263
# i=326/3263
# i=327/3263
# i=328/3263
# i=329/3263
# i=330/3263
# i=331/3263
# i=332/3263
# i=333/3263
# i=334/3263
# i=335/3263
# i=336/3263
# i=337/3263
# i=338/3263
# i=339/3263
# i=340/3263
# i=341/3263
# i=342/3263
# i=343/3263
# i=344/3263
# i=345/3263
# i=346/3263
# i=347/3263
# i=348/3263
# i=349/3263
# i=350/3263
# i=351/3263
# i=352/3263
# i=353/3263
# i=354/3263
# i=355/3263
# i=356/3263
# i=357/3263
# i=358/3263
# i=359/3263
# i=360/3263
# i=361/3263
# i=362/3263
# i=363/3263
# i=364/3263
# i=365/3263
# i=366/3263
# i=367/3263
# i=368/3263
# i=369/3263
# i=370/3263
# i=371/3263
# i=372/3263
# i=373/3263
# i=374/3263
# i=375/3263
# i=376/3263
# i=377/3263
# i=378/3263
# i=379/3263
# i=380/3263
# i=381/3263
# i=382/3263
# i=383/3263
# i=384/3263
# i=385/3263
# i=386/3263
# i=387/3263
# i=388/3263
# i=389/3263
# i=390/3263
# i=391/3263
# i=392/3263
# i=393/3263
# i=394/3263
# i=395/3263
# i=396/3263
# i=397/3263
# i=398/3263
# i=399/3263
# i=400/3263
# i=401/3263
# i=402/3263
# i=403/3263
# i=404/3263
# i=405/3263
# i=406/3263
# i=407/3263
# i=408/3263
# i=409/3263
# i=410/3263
# i=411/3263
# i=412/3263
# i=413/3263
# i=414/3263
# i=415/3263
# i=416/3263
# i=417/3263
# i=418/3263
# i=419/3263
# i=420/3263
# i=421/3263
# i=422/3263
# i=423/3263
# i=424/3263
# i=425/3263
# i=426/3263
# i=427/3263
# i=428/3263
# i=429/3263
# i=430/3263
# i=431/3263
# i=432/3263
# i=433/3263
# i=434/3263
# i=435/3263
# i=436/3263
# i=437/3263
# i=438/3263
# i=439/3263
# i=440/3263
# i=441/3263
# i=442/3263
# i=443/3263
# i=444/3263
# i=445/3263
# i=446/3263
# i=447/3263
# i=448/3263
# i=449/3263
# i=450/3263
# i=451/3263
# i=452/3263
# i=453/3263
# i=454/3263
# i=455/3263
# i=456/3263
# i=457/3263
# i=458/3263
# i=459/3263
# i=460/3263
# i=461/3263
# i=462/3263
# i=463/3263
# i=464/3263
# i=465/3263
# i=466/3263
# i=467/3263
# i=468/3263
# i=469/3263
# i=470/3263
# i=471/3263
# i=472/3263
# i=473/3263
# i=474/3263
# i=475/3263
# i=476/3263
# i=477/3263
# i=478/3263
# i=479/3263
# i=480/3263
# i=481/3263
# i=482/3263
# i=483/3263
# i=484/3263
# i=485/3263
# i=486/3263
# i=487/3263
# i=488/3263
# i=489/3263
# i=490/3263
# i=491/3263
# i=492/3263
# i=493/3263
# i=494/3263
# i=495/3263
# i=496/3263
# i=497/3263
# i=498/3263
# i=499/3263
# i=500/3263
# i=501/3263
# i=502/3263
# i=503/3263
# i=504/3263
# i=505/3263
# i=506/3263
# i=507/3263
# i=508/3263
# i=509/3263
# i=510/3263
# i=511/3263
# i=512/3263
# i=513/3263
# i=514/3263
# i=515/3263
# i=516/3263
# i=517/3263
# i=518/3263
# i=519/3263
# i=520/3263
# i=521/3263
# i=522/3263
# i=523/3263
# i=524/3263
# i=525/3263
# i=526/3263
# i=527/3263
# i=528/3263
# i=529/3263
# i=530/3263
# i=531/3263
# i=532/3263
# i=533/3263
# i=534/3263
# i=535/3263
# i=536/3263
# i=537/3263
# i=538/3263
# i=539/3263
# i=540/3263
# i=541/3263
# i=542/3263
# i=543/3263
# i=544/3263
# i=545/3263
# i=546/3263
# i=547/3263
# i=548/3263
# i=549/3263
# i=550/3263
# i=551/3263
# i=552/3263
# i=553/3263
# i=554/3263
# i=555/3263
# i=556/3263
# i=557/3263
# i=558/3263
# i=559/3263
# i=560/3263
# i=561/3263
# i=562/3263
# i=563/3263
# i=564/3263
# i=565/3263
# i=566/3263
# i=567/3263
# i=568/3263
# i=569/3263
# i=570/3263
# i=571/3263
# i=572/3263
# i=573/3263
# i=574/3263
# i=575/3263
# i=576/3263
# i=577/3263
# i=578/3263
# i=579/3263
# i=580/3263
# i=581/3263
# i=582/3263
# i=583/3263
# i=584/3263
# i=585/3263
# i=586/3263
# i=587/3263
# i=588/3263
# i=589/3263
# i=590/3263
# i=591/3263
# i=592/3263
# i=593/3263
# i=594/3263
# i=595/3263
# i=596/3263
# i=597/3263
# i=598/3263
# i=599/3263
# i=600/3263
# i=601/3263
# i=602/3263
# i=603/3263
# i=604/3263
# i=605/3263
# i=606/3263
# i=607/3263
# i=608/3263
# i=609/3263
# i=610/3263
# i=611/3263
# i=612/3263
# i=613/3263
# i=614/3263
# i=615/3263
# i=616/3263
# i=617/3263
# i=618/3263
# i=619/3263
# i=620/3263
# i=621/3263
# i=622/3263
# i=623/3263
# i=624/3263
# i=625/3263
# i=626/3263
# i=627/3263
# i=628/3263
# i=629/3263
# i=630/3263
# i=631/3263
# i=632/3263
# i=633/3263
# i=634/3263
# i=635/3263
# i=636/3263
# i=637/3263
# i=638/3263
# i=639/3263
# i=640/3263
# i=641/3263
# i=642/3263
# i=643/3263
# i=644/3263
# i=645/3263
# i=646/3263
# i=647/3263
# i=648/3263
# i=649/3263
# i=650/3263
# i=651/3263
# i=652/3263
# i=653/3263
# i=654/3263
# i=655/3263
# i=656/3263
# i=657/3263
# i=658/3263
# i=659/3263
# i=660/3263
# i=661/3263
# i=662/3263
# i=663/3263
# i=664/3263
# i=665/3263
# i=666/3263
# i=667/3263
# i=668/3263
# i=669/3263
# i=670/3263
# i=671/3263
# i=672/3263
# i=673/3263
# i=674/3263
# i=675/3263
# i=676/3263
# i=677/3263
# i=678/3263
# i=679/3263
# i=680/3263
# i=681/3263
# i=682/3263
# i=683/3263
# i=684/3263
# i=685/3263
# i=686/3263
# i=687/3263
# i=688/3263
# i=689/3263
# i=690/3263
# i=691/3263
# i=692/3263
# i=693/3263
# i=694/3263
# i=695/3263
# i=696/3263
# i=697/3263
# i=698/3263
# i=699/3263
# i=700/3263
# i=701/3263
# i=702/3263
# i=703/3263
# i=704/3263
# i=705/3263
# i=706/3263
# i=707/3263
# i=708/3263
# i=709/3263
# i=710/3263
# i=711/3263
# i=712/3263
# i=713/3263
# i=714/3263
# i=715/3263
# i=716/3263
# i=717/3263
# i=718/3263
# i=719/3263
# i=720/3263
# i=721/3263
# i=722/3263
# i=723/3263
# i=724/3263
# i=725/3263
# i=726/3263
# i=727/3263
# i=728/3263
# i=729/3263
# i=730/3263
# i=731/3263
# i=732/3263
# i=733/3263
# i=734/3263
# i=735/3263
# i=736/3263
# i=737/3263
# i=738/3263
# i=739/3263
# i=740/3263
# i=741/3263
# i=742/3263
# i=743/3263
# i=744/3263
# i=745/3263
# i=746/3263
# i=747/3263
# i=748/3263
# i=749/3263
# i=750/3263
# i=751/3263
# i=752/3263
# i=753/3263
# i=754/3263
# i=755/3263
# i=756/3263
# i=757/3263
# i=758/3263
# i=759/3263
# i=760/3263
# i=761/3263
# i=762/3263
# i=763/3263
# i=764/3263
# i=765/3263
# i=766/3263
# i=767/3263
# i=768/3263
# i=769/3263
# i=770/3263
# i=771/3263
# i=772/3263
# i=773/3263
# i=774/3263
# i=775/3263
# i=776/3263
# i=777/3263
# i=778/3263
# i=779/3263
# i=780/3263
# i=781/3263
# i=782/3263
# i=783/3263
# i=784/3263
# i=785/3263
# i=786/3263
# i=787/3263
# i=788/3263
# i=789/3263
# i=790/3263
# i=791/3263
# i=792/3263
# i=793/3263
# i=794/3263
# i=795/3263
# i=796/3263
# i=797/3263
# i=798/3263
# i=799/3263
# i=800/3263
# i=801/3263
# i=802/3263
# i=803/3263
# i=804/3263
# i=805/3263
# i=806/3263
# i=807/3263
# i=808/3263
# i=809/3263
# i=810/3263
# i=811/3263
# i=812/3263
# i=813/3263
# i=814/3263
# i=815/3263
# i=816/3263
# i=817/3263
# i=818/3263
# i=819/3263
# i=820/3263
# i=821/3263
# i=822/3263
# i=823/3263
# i=824/3263
# i=825/3263
# i=826/3263
# i=827/3263
# i=828/3263
# i=829/3263
# i=830/3263
# i=831/3263
# i=832/3263
# i=833/3263
# i=834/3263
# i=835/3263
# i=836/3263
# i=837/3263
# i=838/3263
# i=839/3263
# i=840/3263
# i=841/3263
# i=842/3263
# i=843/3263
# i=844/3263
# i=845/3263
# i=846/3263
# i=847/3263
# i=848/3263
# i=849/3263
# i=850/3263
# i=851/3263
# i=852/3263
# i=853/3263
# i=854/3263
# i=855/3263
# i=856/3263
# i=857/3263
# i=858/3263
# i=859/3263
# i=860/3263
# i=861/3263
# i=862/3263
# i=863/3263
# i=864/3263
# i=865/3263
# i=866/3263
# i=867/3263
# i=868/3263
# i=869/3263
# i=870/3263
# i=871/3263
# i=872/3263
# i=873/3263
# i=874/3263
# i=875/3263
# i=876/3263
# i=877/3263
# i=878/3263
# i=879/3263
# i=880/3263
# i=881/3263
# i=882/3263
# i=883/3263
# i=884/3263
# i=885/3263
# i=886/3263
# i=887/3263
# i=888/3263
# i=889/3263
# i=890/3263
# i=891/3263
# i=892/3263
# i=893/3263
# i=894/3263
# i=895/3263
# i=896/3263
# i=897/3263
# i=898/3263
# i=899/3263
# i=900/3263
# i=901/3263
# i=902/3263
# i=903/3263
# i=904/3263
# i=905/3263
# i=906/3263
# i=907/3263
# i=908/3263
# i=909/3263
# i=910/3263
# i=911/3263
# i=912/3263
# i=913/3263
# i=914/3263
# i=915/3263
# i=916/3263
# i=917/3263
# i=918/3263
# i=919/3263
# i=920/3263
# i=921/3263
# i=922/3263
# i=923/3263
# i=924/3263
# i=925/3263
# i=926/3263
# i=927/3263
# i=928/3263
# i=929/3263
# i=930/3263
# i=931/3263
# i=932/3263
# i=933/3263
# i=934/3263
# i=935/3263
# i=936/3263
# i=937/3263
# i=938/3263
# i=939/3263
# i=940/3263
# i=941/3263
# i=942/3263
# i=943/3263
# i=944/3263
# i=945/3263
# i=946/3263
# i=947/3263
# i=948/3263
# i=949/3263
# i=950/3263
# i=951/3263
# i=952/3263
# i=953/3263
# i=954/3263
# i=955/3263
# i=956/3263
# i=957/3263
# i=958/3263
# i=959/3263
# i=960/3263
# i=961/3263
# i=962/3263
# i=963/3263
# i=964/3263
# i=965/3263
# i=966/3263
# i=967/3263
# i=968/3263
# i=969/3263
# i=970/3263
# i=971/3263
# i=972/3263
# i=973/3263
# i=974/3263
# i=975/3263
# i=976/3263
# i=977/3263
# i=978/3263
# i=979/3263
# i=980/3263
# i=981/3263
# i=982/3263
# i=983/3263
# i=984/3263
# i=985/3263
# i=986/3263
# i=987/3263
# i=988/3263
# i=989/3263
# i=990/3263
# i=991/3263
# i=992/3263
# i=993/3263
# i=994/3263
# i=995/3263
# i=996/3263
# i=997/3263
# i=998/3263
# i=999/3263
# i=1000/3263
# i=1001/3263
# i=1002/3263
# i=1003/3263
# i=1004/3263
# i=1005/3263
# i=1006/3263
# i=1007/3263
# i=1008/3263
# i=1009/3263
# i=1010/3263
# i=1011/3263
# i=1012/3263
# i=1013/3263
# i=1014/3263
# i=1015/3263
# i=1016/3263
# i=1017/3263
# i=1018/3263
# i=1019/3263
# i=1020/3263
# i=1021/3263
# i=1022/3263
# i=1023/3263
# i=1024/3263
# i=1025/3263
# i=1026/3263
# i=1027/3263
# i=1028/3263
# i=1029/3263
# i=1030/3263
# i=1031/3263
# i=1032/3263
# i=1033/3263
# i=1034/3263
# i=1035/3263
# i=1036/3263
# i=1037/3263
# i=1038/3263
# i=1039/3263
# i=1040/3263
# i=1041/3263
# i=1042/3263
# i=1043/3263
# i=1044/3263
# i=1045/3263
# i=1046/3263
# i=1047/3263
# i=1048/3263
# i=1049/3263
# i=1050/3263
# i=1051/3263
# i=1052/3263
# i=1053/3263
# i=1054/3263
# i=1055/3263
# i=1056/3263
# i=1057/3263
# i=1058/3263
# i=1059/3263
# i=1060/3263
# i=1061/3263
# i=1062/3263
# i=1063/3263
# i=1064/3263
# i=1065/3263
# i=1066/3263
# i=1067/3263
# i=1068/3263
# i=1069/3263
# i=1070/3263
# i=1071/3263
# i=1072/3263
# i=1073/3263
# i=1074/3263
# i=1075/3263
# i=1076/3263
# i=1077/3263
# i=1078/3263
# i=1079/3263
# i=1080/3263
# i=1081/3263
# i=1082/3263
# i=1083/3263
# i=1084/3263
# i=1085/3263
# i=1086/3263
# i=1087/3263
# i=1088/3263
# i=1089/3263
# i=1090/3263
# i=1091/3263
# i=1092/3263
# i=1093/3263
# i=1094/3263
# i=1095/3263
# i=1096/3263
# i=1097/3263
# i=1098/3263
# i=1099/3263
# i=1100/3263
# i=1101/3263
# i=1102/3263
# i=1103/3263
# i=1104/3263
# i=1105/3263
# i=1106/3263
# i=1107/3263
# i=1108/3263
# i=1109/3263
# i=1110/3263
# i=1111/3263
# i=1112/3263
# i=1113/3263
# i=1114/3263
# i=1115/3263
# i=1116/3263
# i=1117/3263
# i=1118/3263
# i=1119/3263
# i=1120/3263
# i=1121/3263
# i=1122/3263
# i=1123/3263
# i=1124/3263
# i=1125/3263
# i=1126/3263
# i=1127/3263
# i=1128/3263
# i=1129/3263
# i=1130/3263
# i=1131/3263
# i=1132/3263
# i=1133/3263
# i=1134/3263
# i=1135/3263
# i=1136/3263
# i=1137/3263
# i=1138/3263
# i=1139/3263
# i=1140/3263
# i=1141/3263
# i=1142/3263
# i=1143/3263
# i=1144/3263
# i=1145/3263
# i=1146/3263
# i=1147/3263
# i=1148/3263
# i=1149/3263
# i=1150/3263
# i=1151/3263
# i=1152/3263
# i=1153/3263
# i=1154/3263
# i=1155/3263
# i=1156/3263
# i=1157/3263
# i=1158/3263
# i=1159/3263
# i=1160/3263
# i=1161/3263
# i=1162/3263
# i=1163/3263
# i=1164/3263
# i=1165/3263
# i=1166/3263
# i=1167/3263
# i=1168/3263
# i=1169/3263
# i=1170/3263
# i=1171/3263
# i=1172/3263
# i=1173/3263
# i=1174/3263
# i=1175/3263
# i=1176/3263
# i=1177/3263
# i=1178/3263
# i=1179/3263
# i=1180/3263
# i=1181/3263
# i=1182/3263
# i=1183/3263
# i=1184/3263
# i=1185/3263
# i=1186/3263
# i=1187/3263
# i=1188/3263
# i=1189/3263
# i=1190/3263
# i=1191/3263
# i=1192/3263
# i=1193/3263
# i=1194/3263
# i=1195/3263
# i=1196/3263
# i=1197/3263
# i=1198/3263
# i=1199/3263
# i=1200/3263
# i=1201/3263
# i=1202/3263
# i=1203/3263
# i=1204/3263
# i=1205/3263
# i=1206/3263
# i=1207/3263
# i=1208/3263
# i=1209/3263
# i=1210/3263
# i=1211/3263
# i=1212/3263
# i=1213/3263
# i=1214/3263
# i=1215/3263
# i=1216/3263
# i=1217/3263
# i=1218/3263
# i=1219/3263
# i=1220/3263
# i=1221/3263
# i=1222/3263
# i=1223/3263
# i=1224/3263
# i=1225/3263
# i=1226/3263
# i=1227/3263
# i=1228/3263
# i=1229/3263
# i=1230/3263
# i=1231/3263
# i=1232/3263
# i=1233/3263
# i=1234/3263
# i=1235/3263
# i=1236/3263
# i=1237/3263
# i=1238/3263
# i=1239/3263
# i=1240/3263
# i=1241/3263
# i=1242/3263
# i=1243/3263
# i=1244/3263
# i=1245/3263
# i=1246/3263
# i=1247/3263
# i=1248/3263
# i=1249/3263
# i=1250/3263
# i=1251/3263
# i=1252/3263
# i=1253/3263
# i=1254/3263
# i=1255/3263
# i=1256/3263
# i=1257/3263
# i=1258/3263
# i=1259/3263
# i=1260/3263
# i=1261/3263
# i=1262/3263
# i=1263/3263
# i=1264/3263
# i=1265/3263
# i=1266/3263
# i=1267/3263
# i=1268/3263
# i=1269/3263
# i=1270/3263
# i=1271/3263
# i=1272/3263
# i=1273/3263
# i=1274/3263
# i=1275/3263
# i=1276/3263
# i=1277/3263
# i=1278/3263
# i=1279/3263
# i=1280/3263
# i=1281/3263
# i=1282/3263
# i=1283/3263
# i=1284/3263
# i=1285/3263
# i=1286/3263
# i=1287/3263
# i=1288/3263
# i=1289/3263
# i=1290/3263
# i=1291/3263
# i=1292/3263
# i=1293/3263
# i=1294/3263
# i=1295/3263
# i=1296/3263
# i=1297/3263
# i=1298/3263
# i=1299/3263
# i=1300/3263
# i=1301/3263
# i=1302/3263
# i=1303/3263
# i=1304/3263
# i=1305/3263
# i=1306/3263
# i=1307/3263
# i=1308/3263
# i=1309/3263
# i=1310/3263
# i=1311/3263
# i=1312/3263
# i=1313/3263
# i=1314/3263
# i=1315/3263
# i=1316/3263
# i=1317/3263
# i=1318/3263
# i=1319/3263
# i=1320/3263
# i=1321/3263
# i=1322/3263
# i=1323/3263
# i=1324/3263
# i=1325/3263
# i=1326/3263
# i=1327/3263
# i=1328/3263
# i=1329/3263
# i=1330/3263
# i=1331/3263
# i=1332/3263
# i=1333/3263
# i=1334/3263
# i=1335/3263
# i=1336/3263
# i=1337/3263
# i=1338/3263
# i=1339/3263
# i=1340/3263
# i=1341/3263
# i=1342/3263
# i=1343/3263
# i=1344/3263
# i=1345/3263
# i=1346/3263
# i=1347/3263
# i=1348/3263
# i=1349/3263
# i=1350/3263
# i=1351/3263
# i=1352/3263
# i=1353/3263
# i=1354/3263
# i=1355/3263
# i=1356/3263
# i=1357/3263
# i=1358/3263
# i=1359/3263
# i=1360/3263
# i=1361/3263
# i=1362/3263
# i=1363/3263
# i=1364/3263
# i=1365/3263
# i=1366/3263
# i=1367/3263
# i=1368/3263
# i=1369/3263
# i=1370/3263
# i=1371/3263
# i=1372/3263
# i=1373/3263
# i=1374/3263
# i=1375/3263
# i=1376/3263
# i=1377/3263
# i=1378/3263
# i=1379/3263
# i=1380/3263
# i=1381/3263
# i=1382/3263
# i=1383/3263
# i=1384/3263
# i=1385/3263
# i=1386/3263
# i=1387/3263
# i=1388/3263
# i=1389/3263
# i=1390/3263
# i=1391/3263
# i=1392/3263
# i=1393/3263
# i=1394/3263
# i=1395/3263
# i=1396/3263
# i=1397/3263
# i=1398/3263
# i=1399/3263
# i=1400/3263
# i=1401/3263
# i=1402/3263
# i=1403/3263
# i=1404/3263
# i=1405/3263
# i=1406/3263
# i=1407/3263
# i=1408/3263
# i=1409/3263
# i=1410/3263
# i=1411/3263
# i=1412/3263
# i=1413/3263
# i=1414/3263
# i=1415/3263
# i=1416/3263
# i=1417/3263
# i=1418/3263
# i=1419/3263
# i=1420/3263
# i=1421/3263
# i=1422/3263
# i=1423/3263
# i=1424/3263
# i=1425/3263
# i=1426/3263
# i=1427/3263
# i=1428/3263
# i=1429/3263
# i=1430/3263
# i=1431/3263
# i=1432/3263
# i=1433/3263
# i=1434/3263
# i=1435/3263
# i=1436/3263
# i=1437/3263
# i=1438/3263
# i=1439/3263
# i=1440/3263
# i=1441/3263
# i=1442/3263
# i=1443/3263
# i=1444/3263
# i=1445/3263
# i=1446/3263
# i=1447/3263
# i=1448/3263
# i=1449/3263
# i=1450/3263
# i=1451/3263
# i=1452/3263
# i=1453/3263
# i=1454/3263
# i=1455/3263
# i=1456/3263
# i=1457/3263
# i=1458/3263
# i=1459/3263
# i=1460/3263
# i=1461/3263
# i=1462/3263
# i=1463/3263
# i=1464/3263
# i=1465/3263
# i=1466/3263
# i=1467/3263
# i=1468/3263
# i=1469/3263
# i=1470/3263
# i=1471/3263
# i=1472/3263
# i=1473/3263
# i=1474/3263
# i=1475/3263
# i=1476/3263
# i=1477/3263
# i=1478/3263
# i=1479/3263
# i=1480/3263
# i=1481/3263
# i=1482/3263
# i=1483/3263
# i=1484/3263
# i=1485/3263
# i=1486/3263
# i=1487/3263
# i=1488/3263
# i=1489/3263
# i=1490/3263
# i=1491/3263
# i=1492/3263
# i=1493/3263
# i=1494/3263
# i=1495/3263
# i=1496/3263
# i=1497/3263
# i=1498/3263
# i=1499/3263
# i=1500/3263
# i=1501/3263
# i=1502/3263
# i=1503/3263
# i=1504/3263
# i=1505/3263
# i=1506/3263
# i=1507/3263
# i=1508/3263
# i=1509/3263
# i=1510/3263
# i=1511/3263
# i=1512/3263
# i=1513/3263
# i=1514/3263
# i=1515/3263
# i=1516/3263
# i=1517/3263
# i=1518/3263
# i=1519/3263
# i=1520/3263
# i=1521/3263
# i=1522/3263
# i=1523/3263
# i=1524/3263
# i=1525/3263
# i=1526/3263
# i=1527/3263
# i=1528/3263
# i=1529/3263
# i=1530/3263
# i=1531/3263
# i=1532/3263
# i=1533/3263
# i=1534/3263
# i=1535/3263
# i=1536/3263
# i=1537/3263
# i=1538/3263
# i=1539/3263
# i=1540/3263
# i=1541/3263
# i=1542/3263
# i=1543/3263
# i=1544/3263
# i=1545/3263
# i=1546/3263
# i=1547/3263
# i=1548/3263
# i=1549/3263
# i=1550/3263
# i=1551/3263
# i=1552/3263
# i=1553/3263
# i=1554/3263
# i=1555/3263
# i=1556/3263
# i=1557/3263
# i=1558/3263
# i=1559/3263
# i=1560/3263
# i=1561/3263
# i=1562/3263
# i=1563/3263
# i=1564/3263
# i=1565/3263
# i=1566/3263
# i=1567/3263
# i=1568/3263
# i=1569/3263
# i=1570/3263
# i=1571/3263
# i=1572/3263
# i=1573/3263
# i=1574/3263
# i=1575/3263
# i=1576/3263
# i=1577/3263
# i=1578/3263
# i=1579/3263
# i=1580/3263
# i=1581/3263
# i=1582/3263
# i=1583/3263
# i=1584/3263
# i=1585/3263
# i=1586/3263
# i=1587/3263
# i=1588/3263
# i=1589/3263
# i=1590/3263
# i=1591/3263
# i=1592/3263
# i=1593/3263
# i=1594/3263
# i=1595/3263
# i=1596/3263
# i=1597/3263
# i=1598/3263
# i=1599/3263
# i=1600/3263
# i=1601/3263
# i=1602/3263
# i=1603/3263
# i=1604/3263
# i=1605/3263
# i=1606/3263
# i=1607/3263
# i=1608/3263
# i=1609/3263
# i=1610/3263
# i=1611/3263
# i=1612/3263
# i=1613/3263
# i=1614/3263
# i=1615/3263
# i=1616/3263
# i=1617/3263
# i=1618/3263
# i=1619/3263
# i=1620/3263
# i=1621/3263
# i=1622/3263
# i=1623/3263
# i=1624/3263
# i=1625/3263
# i=1626/3263
# i=1627/3263
# i=1628/3263
# i=1629/3263
# i=1630/3263
# i=1631/3263
# i=1632/3263
# i=1633/3263
# i=1634/3263
# i=1635/3263
# i=1636/3263
# i=1637/3263
# i=1638/3263
# i=1639/3263
# i=1640/3263
# i=1641/3263
# i=1642/3263
# i=1643/3263
# i=1644/3263
# i=1645/3263
# i=1646/3263
# i=1647/3263
# i=1648/3263
# i=1649/3263
# i=1650/3263
# i=1651/3263
# i=1652/3263
# i=1653/3263
# i=1654/3263
# i=1655/3263
# i=1656/3263
# i=1657/3263
# i=1658/3263
# i=1659/3263
# i=1660/3263
# i=1661/3263
# i=1662/3263
# i=1663/3263
# i=1664/3263
# i=1665/3263
# i=1666/3263
# i=1667/3263
# i=1668/3263
# i=1669/3263
# i=1670/3263
# i=1671/3263
# i=1672/3263
# i=1673/3263
# i=1674/3263
# i=1675/3263
# i=1676/3263
# i=1677/3263
# i=1678/3263
# i=1679/3263
# i=1680/3263
# i=1681/3263
# i=1682/3263
# i=1683/3263
# i=1684/3263
# i=1685/3263
# i=1686/3263
# i=1687/3263
# i=1688/3263
# i=1689/3263
# i=1690/3263
# i=1691/3263
# i=1692/3263
# i=1693/3263
# i=1694/3263
# i=1695/3263
# i=1696/3263
# i=1697/3263
# i=1698/3263
# i=1699/3263
# i=1700/3263
# i=1701/3263
# i=1702/3263
# i=1703/3263
# i=1704/3263
# i=1705/3263
# i=1706/3263
# i=1707/3263
# i=1708/3263
# i=1709/3263
# i=1710/3263
# i=1711/3263
# i=1712/3263
# i=1713/3263
# i=1714/3263
# i=1715/3263
# i=1716/3263
# i=1717/3263
# i=1718/3263
# i=1719/3263
# i=1720/3263
# i=1721/3263
# i=1722/3263
# i=1723/3263
# i=1724/3263
# i=1725/3263
# i=1726/3263
# i=1727/3263
# i=1728/3263
# i=1729/3263
# i=1730/3263
# i=1731/3263
# i=1732/3263
# i=1733/3263
# i=1734/3263
# i=1735/3263
# i=1736/3263
# i=1737/3263
# i=1738/3263
# i=1739/3263
# i=1740/3263
# i=1741/3263
# i=1742/3263
# i=1743/3263
# i=1744/3263
# i=1745/3263
# i=1746/3263
# i=1747/3263
# i=1748/3263
# i=1749/3263
# i=1750/3263
# i=1751/3263
# i=1752/3263
# i=1753/3263
# i=1754/3263
# i=1755/3263
# i=1756/3263
# i=1757/3263
# i=1758/3263
# i=1759/3263
# i=1760/3263
# i=1761/3263
# i=1762/3263
# i=1763/3263
# i=1764/3263
# i=1765/3263
# i=1766/3263
# i=1767/3263
# i=1768/3263
# i=1769/3263
# i=1770/3263
# i=1771/3263
# i=1772/3263
# i=1773/3263
# i=1774/3263
# i=1775/3263
# i=1776/3263
# i=1777/3263
# i=1778/3263
# i=1779/3263
# i=1780/3263
# i=1781/3263
# i=1782/3263
# i=1783/3263
# i=1784/3263
# i=1785/3263
# i=1786/3263
# i=1787/3263
# i=1788/3263
# i=1789/3263
# i=1790/3263
# i=1791/3263
# i=1792/3263
# i=1793/3263
# i=1794/3263
# i=1795/3263
# i=1796/3263
# i=1797/3263
# i=1798/3263
# i=1799/3263
# i=1800/3263
# i=1801/3263
# i=1802/3263
# i=1803/3263
# i=1804/3263
# i=1805/3263
# i=1806/3263
# i=1807/3263
# i=1808/3263
# i=1809/3263
# i=1810/3263
# i=1811/3263
# i=1812/3263
# i=1813/3263
# i=1814/3263
# i=1815/3263
# i=1816/3263
# i=1817/3263
# i=1818/3263
# i=1819/3263
# i=1820/3263
# i=1821/3263
# i=1822/3263
# i=1823/3263
# i=1824/3263
# i=1825/3263
# i=1826/3263
# i=1827/3263
# i=1828/3263
# i=1829/3263
# i=1830/3263
# i=1831/3263
# i=1832/3263
# i=1833/3263
# i=1834/3263
# i=1835/3263
# i=1836/3263
# i=1837/3263
# i=1838/3263
# i=1839/3263
# i=1840/3263
# i=1841/3263
# i=1842/3263
# i=1843/3263
# i=1844/3263
# i=1845/3263
# i=1846/3263
# i=1847/3263
# i=1848/3263
# i=1849/3263
# i=1850/3263
# i=1851/3263
# i=1852/3263
# i=1853/3263
# i=1854/3263
# i=1855/3263
# i=1856/3263
# i=1857/3263
# i=1858/3263
# i=1859/3263
# i=1860/3263
# i=1861/3263
# i=1862/3263
# i=1863/3263
# i=1864/3263
# i=1865/3263
# i=1866/3263
# i=1867/3263
# i=1868/3263
# i=1869/3263
# i=1870/3263
# i=1871/3263
# i=1872/3263
# i=1873/3263
# i=1874/3263
# i=1875/3263
# i=1876/3263
# i=1877/3263
# i=1878/3263
# i=1879/3263
# i=1880/3263
# i=1881/3263
# i=1882/3263
# i=1883/3263
# i=1884/3263
# i=1885/3263
# i=1886/3263
# i=1887/3263
# i=1888/3263
# i=1889/3263
# i=1890/3263
# i=1891/3263
# i=1892/3263
# i=1893/3263
# i=1894/3263
# i=1895/3263
# i=1896/3263
# i=1897/3263
# i=1898/3263
# i=1899/3263
# i=1900/3263
# i=1901/3263
# i=1902/3263
# i=1903/3263
# i=1904/3263
# i=1905/3263
# i=1906/3263
# i=1907/3263
# i=1908/3263
# i=1909/3263
# i=1910/3263
# i=1911/3263
# i=1912/3263
# i=1913/3263
# i=1914/3263
# i=1915/3263
# i=1916/3263
# i=1917/3263
# i=1918/3263
# i=1919/3263
# i=1920/3263
# i=1921/3263
# i=1922/3263
# i=1923/3263
# i=1924/3263
# i=1925/3263
# i=1926/3263
# i=1927/3263
# i=1928/3263
# i=1929/3263
# i=1930/3263
# i=1931/3263
# i=1932/3263
# i=1933/3263
# i=1934/3263
# i=1935/3263
# i=1936/3263
# i=1937/3263
# i=1938/3263
# i=1939/3263
# i=1940/3263
# i=1941/3263
# i=1942/3263
# i=1943/3263
# i=1944/3263
# i=1945/3263
# i=1946/3263
# i=1947/3263
# i=1948/3263
# i=1949/3263
# i=1950/3263
# i=1951/3263
# i=1952/3263
# i=1953/3263
# i=1954/3263
# i=1955/3263
# i=1956/3263
# i=1957/3263
# i=1958/3263
# i=1959/3263
# i=1960/3263
# i=1961/3263
# i=1962/3263
# i=1963/3263
# i=1964/3263
# i=1965/3263
# i=1966/3263
# i=1967/3263
# i=1968/3263
# i=1969/3263
# i=1970/3263
# i=1971/3263
# i=1972/3263
# i=1973/3263
# i=1974/3263
# i=1975/3263
# i=1976/3263
# i=1977/3263
# i=1978/3263
# i=1979/3263
# i=1980/3263
# i=1981/3263
# i=1982/3263
# i=1983/3263
# i=1984/3263
# i=1985/3263
# i=1986/3263
# i=1987/3263
# i=1988/3263
# i=1989/3263
# i=1990/3263
# i=1991/3263
# i=1992/3263
# i=1993/3263
# i=1994/3263
# i=1995/3263
# i=1996/3263
# i=1997/3263
# i=1998/3263
# i=1999/3263
# i=2000/3263
# i=2001/3263
# i=2002/3263
# i=2003/3263
# i=2004/3263
# i=2005/3263
# i=2006/3263
# i=2007/3263
# i=2008/3263
# i=2009/3263
# i=2010/3263
# i=2011/3263
# i=2012/3263
# i=2013/3263
# i=2014/3263
# i=2015/3263
# i=2016/3263
# i=2017/3263
# i=2018/3263
# i=2019/3263
# i=2020/3263
# i=2021/3263
# i=2022/3263
# i=2023/3263
# i=2024/3263
# i=2025/3263
# i=2026/3263
# i=2027/3263
# i=2028/3263
# i=2029/3263
# i=2030/3263
# i=2031/3263
# i=2032/3263
# i=2033/3263
# i=2034/3263
# i=2035/3263
# i=2036/3263
# i=2037/3263
# i=2038/3263
# i=2039/3263
# i=2040/3263
# i=2041/3263
# i=2042/3263
# i=2043/3263
# i=2044/3263
# i=2045/3263
# i=2046/3263
# i=2047/3263
# i=2048/3263
# i=2049/3263
# i=2050/3263
# i=2051/3263
# i=2052/3263
# i=2053/3263
# i=2054/3263
# i=2055/3263
# i=2056/3263
# i=2057/3263
# i=2058/3263
# i=2059/3263
# i=2060/3263
# i=2061/3263
# i=2062/3263
# i=2063/3263
# i=2064/3263
# i=2065/3263
# i=2066/3263
# i=2067/3263
# i=2068/3263
# i=2069/3263
# i=2070/3263
# i=2071/3263
# i=2072/3263
# i=2073/3263
# i=2074/3263
# i=2075/3263
# i=2076/3263
# i=2077/3263
# i=2078/3263
# i=2079/3263
# i=2080/3263
# i=2081/3263
# i=2082/3263
# i=2083/3263
# i=2084/3263
# i=2085/3263
# i=2086/3263
# i=2087/3263
# i=2088/3263
# i=2089/3263
# i=2090/3263
# i=2091/3263
# i=2092/3263
# i=2093/3263
# i=2094/3263
# i=2095/3263
# i=2096/3263
# i=2097/3263
# i=2098/3263
# i=2099/3263
# i=2100/3263
# i=2101/3263
# i=2102/3263
# i=2103/3263
# i=2104/3263
# i=2105/3263
# i=2106/3263
# i=2107/3263
# i=2108/3263
# i=2109/3263
# i=2110/3263
# i=2111/3263
# i=2112/3263
# i=2113/3263
# i=2114/3263
# i=2115/3263
# i=2116/3263
# i=2117/3263
# i=2118/3263
# i=2119/3263
# i=2120/3263
# i=2121/3263
# i=2122/3263
# i=2123/3263
# i=2124/3263
# i=2125/3263
# i=2126/3263
# i=2127/3263
# i=2128/3263
# i=2129/3263
# i=2130/3263
# i=2131/3263
# i=2132/3263
# i=2133/3263
# i=2134/3263
# i=2135/3263
# i=2136/3263
# i=2137/3263
# i=2138/3263
# i=2139/3263
# i=2140/3263
# i=2141/3263
# i=2142/3263
# i=2143/3263
# i=2144/3263
# i=2145/3263
# i=2146/3263
# i=2147/3263
# i=2148/3263
# i=2149/3263
# i=2150/3263
# i=2151/3263
# i=2152/3263
# i=2153/3263
# i=2154/3263
# i=2155/3263
# i=2156/3263
# i=2157/3263
# i=2158/3263
# i=2159/3263
# i=2160/3263
# i=2161/3263
# i=2162/3263
# i=2163/3263
# i=2164/3263
# i=2165/3263
# i=2166/3263
# i=2167/3263
# i=2168/3263
# i=2169/3263
# i=2170/3263
# i=2171/3263
# i=2172/3263
# i=2173/3263
# i=2174/3263
# i=2175/3263
# i=2176/3263
# i=2177/3263
# i=2178/3263
# i=2179/3263
# i=2180/3263
# i=2181/3263
# i=2182/3263
# i=2183/3263
# i=2184/3263
# i=2185/3263
# i=2186/3263
# i=2187/3263
# i=2188/3263
# i=2189/3263
# i=2190/3263
# i=2191/3263
# i=2192/3263
# i=2193/3263
# i=2194/3263
# i=2195/3263
# i=2196/3263
# i=2197/3263
# i=2198/3263
# i=2199/3263
# i=2200/3263
# i=2201/3263
# i=2202/3263
# i=2203/3263
# i=2204/3263
# i=2205/3263
# i=2206/3263
# i=2207/3263
# i=2208/3263
# i=2209/3263
# i=2210/3263
# i=2211/3263
# i=2212/3263
# i=2213/3263
# i=2214/3263
# i=2215/3263
# i=2216/3263
# i=2217/3263
# i=2218/3263
# i=2219/3263
# i=2220/3263
# i=2221/3263
# i=2222/3263
# i=2223/3263
# i=2224/3263
# i=2225/3263
# i=2226/3263
# i=2227/3263
# i=2228/3263
# i=2229/3263
# i=2230/3263
# i=2231/3263
# i=2232/3263
# i=2233/3263
# i=2234/3263
# i=2235/3263
# i=2236/3263
# i=2237/3263
# i=2238/3263
# i=2239/3263
# i=2240/3263
# i=2241/3263
# i=2242/3263
# i=2243/3263
# i=2244/3263
# i=2245/3263
# i=2246/3263
# i=2247/3263
# i=2248/3263
# i=2249/3263
# i=2250/3263
# i=2251/3263
# i=2252/3263
# i=2253/3263
# i=2254/3263
# i=2255/3263
# i=2256/3263
# i=2257/3263
# i=2258/3263
# i=2259/3263
# i=2260/3263
# i=2261/3263
# i=2262/3263
# i=2263/3263
# i=2264/3263
# i=2265/3263
# i=2266/3263
# i=2267/3263
# i=2268/3263
# i=2269/3263
# i=2270/3263
# i=2271/3263
# i=2272/3263
# i=2273/3263
# i=2274/3263
# i=2275/3263
# i=2276/3263
# i=2277/3263
# i=2278/3263
# i=2279/3263
# i=2280/3263
# i=2281/3263
# i=2282/3263
# i=2283/3263
# i=2284/3263
# i=2285/3263
# i=2286/3263
# i=2287/3263
# i=2288/3263
# i=2289/3263
# i=2290/3263
# i=2291/3263
# i=2292/3263
# i=2293/3263
# i=2294/3263
# i=2295/3263
# i=2296/3263
# i=2297/3263
# i=2298/3263
# i=2299/3263
# i=2300/3263
# i=2301/3263
# i=2302/3263
# i=2303/3263
# i=2304/3263
# i=2305/3263
# i=2306/3263
# i=2307/3263
# i=2308/3263
# i=2309/3263
# i=2310/3263
# i=2311/3263
# i=2312/3263
# i=2313/3263
# i=2314/3263
# i=2315/3263
# i=2316/3263
# i=2317/3263
# i=2318/3263
# i=2319/3263
# i=2320/3263
# i=2321/3263
# i=2322/3263
# i=2323/3263
# i=2324/3263
# i=2325/3263
# i=2326/3263
# i=2327/3263
# i=2328/3263
# i=2329/3263
# i=2330/3263
# i=2331/3263
# i=2332/3263
# i=2333/3263
# i=2334/3263
# i=2335/3263
# i=2336/3263
# i=2337/3263
# i=2338/3263
# i=2339/3263
# i=2340/3263
# i=2341/3263
# i=2342/3263
# i=2343/3263
# i=2344/3263
# i=2345/3263
# i=2346/3263
# i=2347/3263
# i=2348/3263
# i=2349/3263
# i=2350/3263
# i=2351/3263
# i=2352/3263
# i=2353/3263
# i=2354/3263
# i=2355/3263
# i=2356/3263
# i=2357/3263
# i=2358/3263
# i=2359/3263
# i=2360/3263
# i=2361/3263
# i=2362/3263
# i=2363/3263
# i=2364/3263
# i=2365/3263
# i=2366/3263
# i=2367/3263
# i=2368/3263
# i=2369/3263
# i=2370/3263
# i=2371/3263
# i=2372/3263
# i=2373/3263
# i=2374/3263
# i=2375/3263
# i=2376/3263
# i=2377/3263
# i=2378/3263
# i=2379/3263
# i=2380/3263
# i=2381/3263
# i=2382/3263
# i=2383/3263
# i=2384/3263
# i=2385/3263
# i=2386/3263
# i=2387/3263
# i=2388/3263
# i=2389/3263
# i=2390/3263
# i=2391/3263
# i=2392/3263
# i=2393/3263
# i=2394/3263
# i=2395/3263
# i=2396/3263
# i=2397/3263
# i=2398/3263
# i=2399/3263
# i=2400/3263
# i=2401/3263
# i=2402/3263
# i=2403/3263
# i=2404/3263
# i=2405/3263
# i=2406/3263
# i=2407/3263
# i=2408/3263
# i=2409/3263
# i=2410/3263
# i=2411/3263
# i=2412/3263
# i=2413/3263
# i=2414/3263
# i=2415/3263
# i=2416/3263
# i=2417/3263
# i=2418/3263
# i=2419/3263
# i=2420/3263
# i=2421/3263
# i=2422/3263
# i=2423/3263
# i=2424/3263
# i=2425/3263
# i=2426/3263
# i=2427/3263
# i=2428/3263
# i=2429/3263
# i=2430/3263
# i=2431/3263
# i=2432/3263
# i=2433/3263
# i=2434/3263
# i=2435/3263
# i=2436/3263
# i=2437/3263
# i=2438/3263
# i=2439/3263
# i=2440/3263
# i=2441/3263
# i=2442/3263
# i=2443/3263
# i=2444/3263
# i=2445/3263
# i=2446/3263
# i=2447/3263
# i=2448/3263
# i=2449/3263
# i=2450/3263
# i=2451/3263
# i=2452/3263
# i=2453/3263
# i=2454/3263
# i=2455/3263
# i=2456/3263
# i=2457/3263
# i=2458/3263
# i=2459/3263
# i=2460/3263
# i=2461/3263
# i=2462/3263
# i=2463/3263
# i=2464/3263
# i=2465/3263
# i=2466/3263
# i=2467/3263
# i=2468/3263
# i=2469/3263
# i=2470/3263
# i=2471/3263
# i=2472/3263
# i=2473/3263
# i=2474/3263
# i=2475/3263
# i=2476/3263
# i=2477/3263
# i=2478/3263
# i=2479/3263
# i=2480/3263
# i=2481/3263
# i=2482/3263
# i=2483/3263
# i=2484/3263
# i=2485/3263
# i=2486/3263
# i=2487/3263
# i=2488/3263
# i=2489/3263
# i=2490/3263
# i=2491/3263
# i=2492/3263
# i=2493/3263
# i=2494/3263
# i=2495/3263
# i=2496/3263
# i=2497/3263
# i=2498/3263
# i=2499/3263
# i=2500/3263
# i=2501/3263
# i=2502/3263
# i=2503/3263
# i=2504/3263
# i=2505/3263
# i=2506/3263
# i=2507/3263
# i=2508/3263
# i=2509/3263
# i=2510/3263
# i=2511/3263
# i=2512/3263
# i=2513/3263
# i=2514/3263
# i=2515/3263
# i=2516/3263
# i=2517/3263
# i=2518/3263
# i=2519/3263
# i=2520/3263
# i=2521/3263
# i=2522/3263
# i=2523/3263
# i=2524/3263
# i=2525/3263
# i=2526/3263
# i=2527/3263
# i=2528/3263
# i=2529/3263
# i=2530/3263
# i=2531/3263
# i=2532/3263
# i=2533/3263
# i=2534/3263
# i=2535/3263
# i=2536/3263
# i=2537/3263
# i=2538/3263
# i=2539/3263
# i=2540/3263
# i=2541/3263
# i=2542/3263
# i=2543/3263
# i=2544/3263
# i=2545/3263
# i=2546/3263
# i=2547/3263
# i=2548/3263
# i=2549/3263
# i=2550/3263
# i=2551/3263
# i=2552/3263
# i=2553/3263
# i=2554/3263
# i=2555/3263
# i=2556/3263
# i=2557/3263
# i=2558/3263
# i=2559/3263
# i=2560/3263
# i=2561/3263
# i=2562/3263
# i=2563/3263
# i=2564/3263
# i=2565/3263
# i=2566/3263
# i=2567/3263
# i=2568/3263
# i=2569/3263
# i=2570/3263
# i=2571/3263
# i=2572/3263
# i=2573/3263
# i=2574/3263
# i=2575/3263
# i=2576/3263
# i=2577/3263
# i=2578/3263
# i=2579/3263
# i=2580/3263
# i=2581/3263
# i=2582/3263
# i=2583/3263
# i=2584/3263
# i=2585/3263
# i=2586/3263
# i=2587/3263
# i=2588/3263
# i=2589/3263
# i=2590/3263
# i=2591/3263
# i=2592/3263
# i=2593/3263
# i=2594/3263
# i=2595/3263
# i=2596/3263
# i=2597/3263
# i=2598/3263
# i=2599/3263
# i=2600/3263
# i=2601/3263
# i=2602/3263
# i=2603/3263
# i=2604/3263
# i=2605/3263
# i=2606/3263
# i=2607/3263
# i=2608/3263
# i=2609/3263
# i=2610/3263
# i=2611/3263
# i=2612/3263
# i=2613/3263
# i=2614/3263
# i=2615/3263
# i=2616/3263
# i=2617/3263
# i=2618/3263
# i=2619/3263
# i=2620/3263
# i=2621/3263
# i=2622/3263
# i=2623/3263
# i=2624/3263
# i=2625/3263
# i=2626/3263
# i=2627/3263
# i=2628/3263
# i=2629/3263
# i=2630/3263
# i=2631/3263
# i=2632/3263
# i=2633/3263
# i=2634/3263
# i=2635/3263
# i=2636/3263
# i=2637/3263
# i=2638/3263
# i=2639/3263
# i=2640/3263
# i=2641/3263
# i=2642/3263
# i=2643/3263
# i=2644/3263
# i=2645/3263
# i=2646/3263
# i=2647/3263
# i=2648/3263
# i=2649/3263
# i=2650/3263
# i=2651/3263
# i=2652/3263
# i=2653/3263
# i=2654/3263
# i=2655/3263
# i=2656/3263
# i=2657/3263
# i=2658/3263
# i=2659/3263
# i=2660/3263
# i=2661/3263
# i=2662/3263
# i=2663/3263
# i=2664/3263
# i=2665/3263
# i=2666/3263
# i=2667/3263
# i=2668/3263
# i=2669/3263
# i=2670/3263
# i=2671/3263
# i=2672/3263
# i=2673/3263
# i=2674/3263
# i=2675/3263
# i=2676/3263
# i=2677/3263
# i=2678/3263
# i=2679/3263
# i=2680/3263
# i=2681/3263
# i=2682/3263
# i=2683/3263
# i=2684/3263
# i=2685/3263
# i=2686/3263
# i=2687/3263
# i=2688/3263
# i=2689/3263
# i=2690/3263
# i=2691/3263
# i=2692/3263
# i=2693/3263
# i=2694/3263
# i=2695/3263
# i=2696/3263
# i=2697/3263
# i=2698/3263
# i=2699/3263
# i=2700/3263
# i=2701/3263
# i=2702/3263
# i=2703/3263
# i=2704/3263
# i=2705/3263
# i=2706/3263
# i=2707/3263
# i=2708/3263
# i=2709/3263
# i=2710/3263
# i=2711/3263
# i=2712/3263
# i=2713/3263
# i=2714/3263
# i=2715/3263
# i=2716/3263
# i=2717/3263
# i=2718/3263
# i=2719/3263
# i=2720/3263
# i=2721/3263
# i=2722/3263
# i=2723/3263
# i=2724/3263
# i=2725/3263
# i=2726/3263
# i=2727/3263
# i=2728/3263
# i=2729/3263
# i=2730/3263
# i=2731/3263
# i=2732/3263
# i=2733/3263
# i=2734/3263
# i=2735/3263
# i=2736/3263
# i=2737/3263
# i=2738/3263
# i=2739/3263
# i=2740/3263
# i=2741/3263
# i=2742/3263
# i=2743/3263
# i=2744/3263
# i=2745/3263
# i=2746/3263
# i=2747/3263
# i=2748/3263
# i=2749/3263
# i=2750/3263
# i=2751/3263
# i=2752/3263
# i=2753/3263
# i=2754/3263
# i=2755/3263
# i=2756/3263
# i=2757/3263
# i=2758/3263
# i=2759/3263
# i=2760/3263
# i=2761/3263
# i=2762/3263
# i=2763/3263
# i=2764/3263
# i=2765/3263
# i=2766/3263
# i=2767/3263
# i=2768/3263
# i=2769/3263
# i=2770/3263
# i=2771/3263
# i=2772/3263
# i=2773/3263
# i=2774/3263
# i=2775/3263
# i=2776/3263
# i=2777/3263
# i=2778/3263
# i=2779/3263
# i=2780/3263
# i=2781/3263
# i=2782/3263
# i=2783/3263
# i=2784/3263
# i=2785/3263
# i=2786/3263
# i=2787/3263
# i=2788/3263
# i=2789/3263
# i=2790/3263
# i=2791/3263
# i=2792/3263
# i=2793/3263
# i=2794/3263
# i=2795/3263
# i=2796/3263
# i=2797/3263
# i=2798/3263
# i=2799/3263
# i=2800/3263
# i=2801/3263
# i=2802/3263
# i=2803/3263
# i=2804/3263
# i=2805/3263
# i=2806/3263
# i=2807/3263
# i=2808/3263
# i=2809/3263
# i=2810/3263
# i=2811/3263
# i=2812/3263
# i=2813/3263
# i=2814/3263
# i=2815/3263
# i=2816/3263
# i=2817/3263
# i=2818/3263
# i=2819/3263
# i=2820/3263
# i=2821/3263
# i=2822/3263
# i=2823/3263
# i=2824/3263
# i=2825/3263
# i=2826/3263
# i=2827/3263
# i=2828/3263
# i=2829/3263
# i=2830/3263
# i=2831/3263
# i=2832/3263
# i=2833/3263
# i=2834/3263
# i=2835/3263
# i=2836/3263
# i=2837/3263
# i=2838/3263
# i=2839/3263
# i=2840/3263
# i=2841/3263
# i=2842/3263
# i=2843/3263
# i=2844/3263
# i=2845/3263
# i=2846/3263
# i=2847/3263
# i=2848/3263
# i=2849/3263
# i=2850/3263
# i=2851/3263
# i=2852/3263
# i=2853/3263
# i=2854/3263
# i=2855/3263
# i=2856/3263
# i=2857/3263
# i=2858/3263
# i=2859/3263
# i=2860/3263
# i=2861/3263
# i=2862/3263
# i=2863/3263
# i=2864/3263
# i=2865/3263
# i=2866/3263
# i=2867/3263
# i=2868/3263
# i=2869/3263
# i=2870/3263
# i=2871/3263
# i=2872/3263
# i=2873/3263
# i=2874/3263
# i=2875/3263
# i=2876/3263
# i=2877/3263
# i=2878/3263
# i=2879/3263
# i=2880/3263
# i=2881/3263
# i=2882/3263
# i=2883/3263
# i=2884/3263
# i=2885/3263
# i=2886/3263
# i=2887/3263
# i=2888/3263
# i=2889/3263
# i=2890/3263
# i=2891/3263
# i=2892/3263
# i=2893/3263
# i=2894/3263
# i=2895/3263
# i=2896/3263
# i=2897/3263
# i=2898/3263
# i=2899/3263
# i=2900/3263
# i=2901/3263
# i=2902/3263
# i=2903/3263
# i=2904/3263
# i=2905/3263
# i=2906/3263
# i=2907/3263
# i=2908/3263
# i=2909/3263
# i=2910/3263
# i=2911/3263
# i=2912/3263
# i=2913/3263
# i=2914/3263
# i=2915/3263
# i=2916/3263
# i=2917/3263
# i=2918/3263
# i=2919/3263
# i=2920/3263
# i=2921/3263
# i=2922/3263
# i=2923/3263
# i=2924/3263
# i=2925/3263
# i=2926/3263
# i=2927/3263
# i=2928/3263
# i=2929/3263
# i=2930/3263
# i=2931/3263
# i=2932/3263
# i=2933/3263
# i=2934/3263
# i=2935/3263
# i=2936/3263
# i=2937/3263
# i=2938/3263
# i=2939/3263
# i=2940/3263
# i=2941/3263
# i=2942/3263
# i=2943/3263
# i=2944/3263
# i=2945/3263
# i=2946/3263
# i=2947/3263
# i=2948/3263
# i=2949/3263
# i=2950/3263
# i=2951/3263
# i=2952/3263
# i=2953/3263
# i=2954/3263
# i=2955/3263
# i=2956/3263
# i=2957/3263
# i=2958/3263
# i=2959/3263
# i=2960/3263
# i=2961/3263
# i=2962/3263
# i=2963/3263
# i=2964/3263
# i=2965/3263
# i=2966/3263
# i=2967/3263
# i=2968/3263
# i=2969/3263
# i=2970/3263
# i=2971/3263
# i=2972/3263
# i=2973/3263
# i=2974/3263
# i=2975/3263
# i=2976/3263
# i=2977/3263
# i=2978/3263
# i=2979/3263
# i=2980/3263
# i=2981/3263
# i=2982/3263
# i=2983/3263
# i=2984/3263
# i=2985/3263
# i=2986/3263
# i=2987/3263
# i=2988/3263
# i=2989/3263
# i=2990/3263
# i=2991/3263
# i=2992/3263
# i=2993/3263
# i=2994/3263
# i=2995/3263
# i=2996/3263
# i=2997/3263
# i=2998/3263
# i=2999/3263
# i=3000/3263
# i=3001/3263
# i=3002/3263
# i=3003/3263
# i=3004/3263
# i=3005/3263
# i=3006/3263
# i=3007/3263
# i=3008/3263
# i=3009/3263
# i=3010/3263
# i=3011/3263
# i=3012/3263
# i=3013/3263
# i=3014/3263
# i=3015/3263
# i=3016/3263
# i=3017/3263
# i=3018/3263
# i=3019/3263
# i=3020/3263
# i=3021/3263
# i=3022/3263
# i=3023/3263
# i=3024/3263
# i=3025/3263
# i=3026/3263
# i=3027/3263
# i=3028/3263
# i=3029/3263
# i=3030/3263
# i=3031/3263
# i=3032/3263
# i=3033/3263
# i=3034/3263
# i=3035/3263
# i=3036/3263
# i=3037/3263
# i=3038/3263
# i=3039/3263
# i=3040/3263
# i=3041/3263
# i=3042/3263
# i=3043/3263
# i=3044/3263
# i=3045/3263
# i=3046/3263
# i=3047/3263
# i=3048/3263
# i=3049/3263
# i=3050/3263
# i=3051/3263
# i=3052/3263
# i=3053/3263
# i=3054/3263
# i=3055/3263
# i=3056/3263
# i=3057/3263
# i=3058/3263
# i=3059/3263
# i=3060/3263
# i=3061/3263
# i=3062/3263
# i=3063/3263
# i=3064/3263
# i=3065/3263
# i=3066/3263
# i=3067/3263
# i=3068/3263
# i=3069/3263
# i=3070/3263
# i=3071/3263
# i=3072/3263
# i=3073/3263
# i=3074/3263
# i=3075/3263
# i=3076/3263
# i=3077/3263
# i=3078/3263
# i=3079/3263
# i=3080/3263
# i=3081/3263
# i=3082/3263
# i=3083/3263
# i=3084/3263
# i=3085/3263
# i=3086/3263
# i=3087/3263
# i=3088/3263
# i=3089/3263
# i=3090/3263
# i=3091/3263
# i=3092/3263
# i=3093/3263
# i=3094/3263
# i=3095/3263
# i=3096/3263
# i=3097/3263
# i=3098/3263
# i=3099/3263
# i=3100/3263
# i=3101/3263
# i=3102/3263
# i=3103/3263
# i=3104/3263
# i=3105/3263
# i=3106/3263
# i=3107/3263
# i=3108/3263
# i=3109/3263
# i=3110/3263
# i=3111/3263
# i=3112/3263
# i=3113/3263
# i=3114/3263
# i=3115/3263
# i=3116/3263
# i=3117/3263
# i=3118/3263
# i=3119/3263
# i=3120/3263
# i=3121/3263
# i=3122/3263
# i=3123/3263
# i=3124/3263
# i=3125/3263
# i=3126/3263
# i=3127/3263
# i=3128/3263
# i=3129/3263
# i=3130/3263
# i=3131/3263
# i=3132/3263
# i=3133/3263
# i=3134/3263
# i=3135/3263
# i=3136/3263
# i=3137/3263
# i=3138/3263
# i=3139/3263
# i=3140/3263
# i=3141/3263
# i=3142/3263
# i=3143/3263
# i=3144/3263
# i=3145/3263
# i=3146/3263
# i=3147/3263
# i=3148/3263
# i=3149/3263
# i=3150/3263
# i=3151/3263
# i=3152/3263
# i=3153/3263
# i=3154/3263
# i=3155/3263
# i=3156/3263
# i=3157/3263
# i=3158/3263
# i=3159/3263
# i=3160/3263
# i=3161/3263
# i=3162/3263
# i=3163/3263
# i=3164/3263
# i=3165/3263
# i=3166/3263
# i=3167/3263
# i=3168/3263
# i=3169/3263
# i=3170/3263
# i=3171/3263
# i=3172/3263
# i=3173/3263
# i=3174/3263
# i=3175/3263
# i=3176/3263
# i=3177/3263
# i=3178/3263
# i=3179/3263
# i=3180/3263
# i=3181/3263
# i=3182/3263
# i=3183/3263
# i=3184/3263
# i=3185/3263
# i=3186/3263
# i=3187/3263
# i=3188/3263
# i=3189/3263
# i=3190/3263
# i=3191/3263
# i=3192/3263
# i=3193/3263
# i=3194/3263
# i=3195/3263
# i=3196/3263
# i=3197/3263
# i=3198/3263
# i=3199/3263
# i=3200/3263
# i=3201/3263
# i=3202/3263
# i=3203/3263
# i=3204/3263
# i=3205/3263
# i=3206/3263
# i=3207/3263
# i=3208/3263
# i=3209/3263
# i=3210/3263
# i=3211/3263
# i=3212/3263
# i=3213/3263
# i=3214/3263
# i=3215/3263
# i=3216/3263
# i=3217/3263
# i=3218/3263
# i=3219/3263
# i=3220/3263
# i=3221/3263
# i=3222/3263
# i=3223/3263
# i=3224/3263
# i=3225/3263
# i=3226/3263
# i=3227/3263
# i=3228/3263
# i=3229/3263
# i=3230/3263
# i=3231/3263
# i=3232/3263
# i=3233/3263
# i=3234/3263
# i=3235/3263
# i=3236/3263
# i=3237/3263
# i=3238/3263
# i=3239/3263
# i=3240/3263
# i=3241/3263
# i=3242/3263
# i=3243/3263
# i=3244/3263
# i=3245/3263
# i=3246/3263
# i=3247/3263
# i=3248/3263
# i=3249/3263
# i=3250/3263
# i=3251/3263
# i=3252/3263
# i=3253/3263
# i=3254/3263
# i=3255/3263
# i=3256/3263
# i=3257/3263
# i=3258/3263
# i=3259/3263
# i=3260/3263
# i=3261/3263
# i=3262/3263
#         id  target
# 2406  8051    True

# %%
submission.target = submission.target.apply(lambda x: 1 if x else 0)
submission.to_csv('submission.csv', index=False)

# %%
# Salvăm modelul dacă ne place
model.save_weights('./model.weights.h5')
